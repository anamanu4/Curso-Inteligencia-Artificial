# %% [markdown]
# <a href="https://colab.research.google.com/github/anamanu4/Curso-Inteligencia-Artificial/blob/main/EDA_apuntes_de_clases.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Ejemplos

import librerias

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- ------------------
# absl-py                            1.4.0
# accelerate                         1.3.0
# aiohappyeyeballs                   2.4.4
# aiohttp                            3.11.12
# aiosignal                          1.3.2
# alabaster                          1.0.0
# albucore                           0.0.23
# albumentations                     2.0.3
# ale-py                             0.10.1
# altair                             5.5.0
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.6.0
# arviz                              0.20.0
# astropy                            7.0.0
# astropy-iers-data                  0.2025.2.3.0.32.42
# astunparse                         1.6.3
# atpublic                           4.1.0
# ...

# %%
ls-la
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Feb 11 14:27 ./
# drwxr-xr-x 1 root root 4096 Feb 12 22:19 ../
# drwxr-xr-x 4 root root 4096 Feb 11 14:27 .config/
# drwxr-xr-x 1 root root 4096 Feb 11 14:27 sample_data/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfs=pd.read_csv('https://raw.githubusercontent.com/adiacta/bigdata/refs/heads/master/vivienda_clasif.csv')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-8-0c7ebae761bc> in <cell line: 0>()
# ----> 1 dfs=pd.read_csv('https://raw.githubusercontent.com/adiacta/bigdata/refs/heads/master/vivienda_clasif.csv')
#
# ...

# %%
# prompt: creame 4 arreglos, el primero llamado saldo, que contiene datos sinteticos de saldo bancario,otro arreglo llamado antiguedad que contiene datos de la antiguedad de la cuenta bancaria va de 0 a 10, los dos arreglos en enteros. una matriz de dos columnas que contiene la latitud en la columna 0, y la longitud en la columna1, con datos muy cercanos a bucaramanga, es decir que varie la latitud y longitud en decimales o centecimales. El numero de datos son 20,. la matriz se llama ubicacion. Finalmente quiero que usando column stack me una las matrices y las listas creadas. Defina la semilla aleatoria en 42.

import numpy as np
import pandas as pd

# Set random seed
np.random.seed(42)

# Create saldo array
saldo = np.random.randint(1000, 100000, size=20)

# Create antiguedad array
antiguedad = np.random.randint(0, 11, size=20)

# Create ubicacion matrix (latitude and longitude near Bucaramanga)
# Bucaramanga approximate coordinates: 7.1259° N, 73.1197° W
latitudes = 7.1259 + np.random.uniform(-0.05, 0.05, 20)  # Vary latitude within a small range
longitudes = -73.1197 + np.random.uniform(-0.05, 0.05, 20)  # Vary longitude within a small range
ubicacion = np.column_stack((latitudes, longitudes))


# Combine arrays and matrix using column_stack
combined_data = np.column_stack((saldo, antiguedad, ubicacion))

# Convert to DataFrame (optional, for better visualization)
df = pd.DataFrame(combined_data, columns=['saldo', 'antiguedad', 'latitude', 'longitude'])
df
# Out:
#       saldo  antiguedad  latitude  longitude
# 0   16795.0         4.0  7.077226 -73.130185
# 1    1860.0         0.0  7.170120 -73.077034
# 2   77820.0         9.0  7.132229 -73.096973
# 3   55886.0         5.0  7.114442 -73.137046
# 4    7265.0         8.0  7.077497 -73.112656
# 5   83386.0         0.0  7.098989 -73.117617
# 6   38194.0        10.0  7.100003 -73.073583
# 7   88498.0        10.0  7.144226 -73.085247
# 8   45131.0         9.0  7.136900 -73.094968
# 9   61263.0         2.0  7.159219 -73.115731
# 10  17023.0         6.0  7.093236 -73.111025
# 11  42090.0         3.0  7.115006 -73.073174
# 12  68221.0         8.0  7.094124 -73.108997
# 13  65820.0         2.0  7.151436 -73.142100
# 14   1769.0         4.0  7.118416 -73.140073
# 15  60735.0         2.0  7.096694 -73.153173
# 16  63955.0         6.0  7.132670 -73.168136
# 17  65925.0         4.0  7.079031 -73.127360
# 18  68969.0         8.0  7.160128 -73.130212
# 19   6311.0         6.0  7.120875 -73.140351

# %%
datos_combinados.shape
# Out:
# (20, 4)

# %%
print("Media",np.mean(datos_combinados[0]))
print("Maximo",np.max(datos_combinados[0]))
print("Minimo",np.min(datos_combinados[0]))
# Out:
# Media 4183.237460379929
# Maximo 16795.0
# Minimo -73.12648497639982

# %%
datos_combinados[:,:]
# Out:
# array([[ 1.67950000e+04,  4.00000000e+00,  7.07632650e+00,
#         -7.31264850e+01],
#        [ 1.86000000e+03,  0.00000000e+00,  7.16922018e+00,
#         -7.30733341e+01],
#        [ 7.78200000e+04,  9.00000000e+00,  7.13132882e+00,
#         -7.30932728e+01],
#        [ 5.58860000e+04,  5.00000000e+00,  7.11354165e+00,
#         -7.31333459e+01],
#        [ 7.26500000e+03,  8.00000000e+00,  7.07659663e+00,
#         -7.31089556e+01],
#        [ 8.33860000e+04,  0.00000000e+00,  7.09808938e+00,
#         -7.31139166e+01],
#        [ 3.81940000e+04,  1.00000000e+01,  7.09910255e+00,
#         -7.30698828e+01],
#        [ 8.84980000e+04,  1.00000000e+01,  7.14332635e+00,
#         -7.30815466e+01],
#        [ 4.51310000e+04,  9.00000000e+00,  7.13599967e+00,
#         -7.30912680e+01],
#        [ 6.12630000e+04,  2.00000000e+00,  7.15831949e+00,
#         -7.31120308e+01],
#        [ 1.70230000e+04,  6.00000000e+00,  7.09233647e+00,
#         -7.31073249e+01],
# ...

# %%
datos_combinados[-5:-2,1:3]
# Out:
# array([[2.        , 7.09579417],
#        [6.        , 7.13177003],
#        [4.        , 7.07813133]])

# %%
# prompt: por favor creame una lista de 20 nombres colombianos en un arreglo de numpy que se llama "nombre"

import numpy as np

nombres = np.array([
    "Juan", "Maria", "Jose", "Ana", "Carlos",
    "Sofia", "David", "Laura", "Andres", "Camila",
    "Alejandro", "Valentina", "Sebastian", "Isabella", "Miguel",
    "Daniela", "Nicolas", "Gabriela", "Santiago", "Luisa"
])

# %%
nombres
# Out:
# array(['Juan', 'Maria', 'Jose', 'Ana', 'Carlos', 'Sofia', 'David',
#        'Laura', 'Andres', 'Camila', 'Alejandro', 'Valentina', 'Sebastian',
#        'Isabella', 'Miguel', 'Daniela', 'Nicolas', 'Gabriela', 'Santiago',
#        'Luisa'], dtype='<U9')

# %%
nombres.dtype
# Out:
# dtype('<U9')

# %%
# prompt: Cree un dataframe que una nombres, saldo, antiguedad,latitud,longitud

import pandas as pd
import numpy as np

# Existing code (provided in the prompt) for saldo, antiguedad, ubicacion

# ... (previous code remains unchanged)

# Create a DataFrame with nombres, saldo, antiguedad, latitude, and longitude
df = pd.DataFrame({
    'nombres': nombres,
    'saldo': saldo,
    'antiguedad': antiguedad,
    'latitude': latitudes,
    'longitude': longitudes
})

df
# Out:
#       nombres  saldo  antiguedad  latitude  longitude
# 0        Juan  16795           4  7.077226 -73.130185
# 1       Maria   1860           0  7.170120 -73.077034
# 2        Jose  77820           9  7.132229 -73.096973
# 3         Ana  55886           5  7.114442 -73.137046
# 4      Carlos   7265           8  7.077497 -73.112656
# 5       Sofia  83386           0  7.098989 -73.117617
# 6       David  38194          10  7.100003 -73.073583
# 7       Laura  88498          10  7.144226 -73.085247
# 8      Andres  45131           9  7.136900 -73.094968
# 9      Camila  61263           2  7.159219 -73.115731
# 10  Alejandro  17023           6  7.093236 -73.111025
# 11  Valentina  42090           3  7.115006 -73.073174
# 12  Sebastian  68221           8  7.094124 -73.108997
# 13   Isabella  65820           2  7.151436 -73.142100
# 14     Miguel   1769           4  7.118416 -73.140073
# 15    Daniela  60735           2  7.096694 -73.153173
# ...

# %%
df.to_excel("Datos.xlsx")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# nombres        object
# saldo           int64
# antiguedad      int64
# latitude      float64
# longitude     float64
# dtype: object

# %%
df["saldo"].max()
df.saldo.max()
# Out:
# 88498

# %%
df.describe().T
# Out:
#             count          mean           std          min           25%  \
# saldo        20.0  46845.800000  28684.574478  1769.000000  16966.000000
# antiguedad   20.0      5.300000      3.197038     0.000000      2.750000
# latitude     20.0      7.118623      0.028962     7.077226      7.096052
# longitude    20.0    -73.116782      0.027054   -73.168136    -73.137803
#
#                      50%           75%           max
# saldo       58310.500000  66499.000000  88498.000000
# antiguedad      5.500000      8.000000     10.000000
# latitude        7.116711      7.138731      7.170120
# longitude     -73.116674    -73.096472    -73.073174

# %%
df[df.saldo>70000]
# Out:
#   nombres  saldo  antiguedad  latitude  longitude
# 2    Jose  77820           9  7.132229 -73.096973
# 5   Sofia  83386           0  7.098989 -73.117617
# 7   Laura  88498          10  7.144226 -73.085247

# %%
# prompt: del df mostrar solo las dos primeras columnas y las 10 ultimas filas

# Display the first two columns and the last 10 rows of the DataFrame
print(df.iloc[-10:, :2])
# Out:
#       nombres  saldo
# 10  Alejandro  17023
# 11  Valentina  42090
# 12  Sebastian  68221
# 13   Isabella  65820
# 14     Miguel   1769
# 15    Daniela  60735
# 16    Nicolas  63955
# 17   Gabriela  65925
# 18   Santiago  68969
# 19      Luisa   6311

# %%
print(df.iloc[:10,0:2])
# Out:
#   nombres  saldo
# 0    Juan  16795
# 1   Maria   1860
# 2    Jose  77820
# 3     Ana  55886
# 4  Carlos   7265
# 5   Sofia  83386
# 6   David  38194
# 7   Laura  88498
# 8  Andres  45131
# 9  Camila  61263

# %%
# prompt: de df mostrar el nombre y la antiguedad de las filas 14 a las 18

# Display the 'nombres' and 'antiguedad' columns for rows 14 to 18 (inclusive).
print(df.loc[14:18, ['nombres', 'antiguedad']])
# Out:
#      nombres  antiguedad
# 14    Miguel           4
# 15   Daniela           2
# 16   Nicolas           6
# 17  Gabriela           4
# 18  Santiago           8

# %%
df_copia=df
df_copia
# Out:
#       nombres  saldo  antiguedad  latitude  longitude
# 0        Juan  16795           4  7.077226 -73.130185
# 1       Maria   1860           0  7.170120 -73.077034
# 2        Jose  77820           9  7.132229 -73.096973
# 3         Ana  55886           5  7.114442 -73.137046
# 4      Carlos   7265           8  7.077497 -73.112656
# 5       Sofia  83386           0  7.098989 -73.117617
# 6       David  38194          10  7.100003 -73.073583
# 7       Laura  88498          10  7.144226 -73.085247
# 8      Andres  45131           9  7.136900 -73.094968
# 9      Camila  61263           2  7.159219 -73.115731
# 10  Alejandro  17023           6  7.093236 -73.111025
# 11  Valentina  42090           3  7.115006 -73.073174
# 12  Sebastian  68221           8  7.094124 -73.108997
# 13   Isabella  65820           2  7.151436 -73.142100
# 14     Miguel   1769           4  7.118416 -73.140073
# 15    Daniela  60735           2  7.096694 -73.153173
# ...

# %%
df.saldo.plot(kind="hist",bins=5,title="Histograma de saldo")
# Out:
# <Axes: title={'center': 'Histograma de saldo'}, ylabel='Frequency'>

# %%
df.saldo.iloc[13:18].plot(kind="line")
# Out:
# <Axes: >

# %%
df.saldo.iloc[13:18].plot(kind="pie")
# Out:
# <Axes: ylabel='saldo'>

# %%
import matplotlib.pyplot as plt

fig,ax =plt.subplots()
ax.barh(df.nombres, width=df.antiguedad)
ax.set_title("Bar Plot")
ax.set_xlabel("Nombres")
ax.set_ylabel("Antiguedad")
plt.show()
